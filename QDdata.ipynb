# %%
from initializeBatch import initializeBatch

# %%
initializeBatch('QD_Data/QD_PL', 22, 23)
# Out:
# 22
# data loaded

# %%
from plotSpectra import plotSpectra

# %%
plotSpectra(1)

# %%
from setRange import setRange

# %%
setRange(20, 295, 1000)

# %%
from fitSpectrum import fitSpectrum

# %%
fitSpectrum()
# Out:
# [9.00000000e-02 1.13115903e-01 1.85000000e+00 1.84354649e+00
#  8.26974360e-02 1.07956486e+02 5.61454182e+02]
# Error is:
# [6.11643862e-03 5.87851202e-03 7.48419013e-04 2.91704292e-04
#  3.82216018e-03 2.02848849e+00 3.51501593e+00]

# %%
from fitAllSpectra import fitAllSpectra

# %%
fitAllSpectra(295, 1000, 10)
# Out:
# finished fitting! Series is 104 long.

# %%
from removeError import removeError

# %%
removeError()
# Out:
# 104
# 4
# finished removing high error fit data, length is now 100.

# %%
from plotSeriesParams import plotSeriesParams

# %%
plotSeriesParams()

# %%
from plotCovarParams import plotCovarParams

# %%
plotCovarParams()

# %%
from anticrossingPlots import anticrossingPlots

# %%
from anticrossingPlots import makeCrossingFig

# %%
anticrossingPlots(1.8335, 1.837, 1.841, 1.855)
# Out:
# 1.8309445516432217
# 1.8345708025300627
# 1.839815299144581
# 1.8453430646342726
# nan
# 5
# yeehaw!
